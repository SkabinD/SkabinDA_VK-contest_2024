# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
# !pip install tensorflow_ranking
# import tensorflow_ranking as tfr

from sklearn.metrics import ndcg_score, classification_report, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from imblearn.over_sampling import SMOTE

# %%
df_train = pd.read_csv("/kaggle/input/vk-contest-mle/train_df.csv")
df_test = pd.read_csv("/kaggle/input/vk-contest-mle/test_df.csv")

X_train = df_train[df_train.columns[1:-1]].to_numpy()
X_test = df_test[df_test.columns[1:-1]].to_numpy()

y_train = df_train["target"].to_numpy()
y_test = df_test["target"].to_numpy()

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (15081, 79) (15081,) (1529, 79) (1529,)

# %%
X_scaler = StandardScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
model = Sequential([
    Dense(1024, activation="relu"),
    Dropout(0.2),
    Dense(1024, activation="relu"),
    Dropout(0.2),
    Dense(1, activation="sigmoid")
])

model.compile(optimizer=Adam(learning_rate=1e-3), loss='binary_crossentropy')

# %%
history = model.fit(x=X_train, y=y_train, 
                    batch_size=128, epochs=10,
                    validation_data=[X_test, y_test])
# Out:
# Epoch 1/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.3479 - precision: 0.0000e+00 - val_loss: 0.1053 - val_precision: 0.0000e+00
# Epoch 2/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.1053 - precision: 0.0000e+00 - val_loss: 0.1068 - val_precision: 0.0000e+00
# Epoch 3/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.1005 - precision: 0.0000e+00 - val_loss: 0.1236 - val_precision: 0.0000e+00
# Epoch 4/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.1029 - precision: 0.0000e+00 - val_loss: 0.1059 - val_precision: 0.0000e+00
# Epoch 5/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.1013 - precision: 0.0000e+00 - val_loss: 0.1064 - val_precision: 0.0000e+00
# Epoch 6/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.1030 - precision: 0.0000e+00 - val_loss: 0.1079 - val_precision: 0.0000e+00
# Epoch 7/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.1023 - precision: 0.0000e+00 - val_loss: 0.1050 - val_precision: 0.0000e+00
# Epoch 8/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0988 - precision: 0.0000e+00 - val_loss: 0.1037 - val_precision: 0.0000e+00
# Epoch 9/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1039 - precision: 0.0000e+00 - val_loss: 0.1025 - val_precision: 0.0000e+00
# Epoch 10/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.1063 - precision: 0.0000e+00 - val_loss: 0.1025 - val_precision: 0.0000e+00

# %%
y_pred = model.predict(X_test)
print(ndcg_score([y_test],[y_pred[:, 0]]))
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 0.44471734223611226

# %% [markdown]
# **best score:** 0.44471734223611226
# # Scaled

# %%
model = Sequential([
    Dense(1024, activation="relu"),
    Dropout(0.2),
    Dense(1024, activation="relu"),
    Dropout(0.2),
    Dense(1, activation="sigmoid")
])

model.compile(optimizer=Adam(learning_rate=1e-3), loss='binary_crossentropy')

history = model.fit(x=X_train_scaled, y=y_train, 
                    batch_size=128, epochs=10,
                    validation_data=[X_test_scaled, y_test])

y_pred = model.predict(X_test_scaled)
print(ndcg_score([y_test],[y_pred[:, 0]]))
# Out:
# Epoch 1/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.1545 - val_loss: 0.1074
# Epoch 2/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.0948 - val_loss: 0.1039
# Epoch 3/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0897 - val_loss: 0.1062
# Epoch 4/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0865 - val_loss: 0.1098
# Epoch 5/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0745 - val_loss: 0.1347
# Epoch 6/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0706 - val_loss: 0.1146
# Epoch 7/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0633 - val_loss: 0.1371
# Epoch 8/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0594 - val_loss: 0.1372
# Epoch 9/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0547 - val_loss: 0.1757
# Epoch 10/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0518 - val_loss: 0.1785
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 0.42844412357074346

# %% [markdown]
# # SMOTE

# %%
df_train = pd.read_csv("/kaggle/input/vk-contest-mle/train_df.csv")
df_test = pd.read_csv("/kaggle/input/vk-contest-mle/test_df.csv")

X_train = df_train[df_train.columns[1:-1]].to_numpy()
X_test = df_test[df_test.columns[1:-1]].to_numpy()

y_train = df_train["target"].to_numpy()
y_test = df_test["target"].to_numpy()

X_train, y_train = SMOTE().fit_resample(X_train, y_train)

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)

model = Sequential([
    Dense(1024, activation="relu"),
    Dropout(0.2),
    Dense(1024, activation="relu"),
    Dropout(0.2),
    Dense(1, activation="sigmoid")
])

model.compile(optimizer=Adam(learning_rate=1e-3), loss='binary_crossentropy')

history = model.fit(x=X_train, y=y_train, 
                    batch_size=128, epochs=100,
                    validation_data=[X_test, y_test])

y_pred = model.predict(X_test)
print(ndcg_score([y_test],[y_pred[:, 0]]))
# Out:
# (29518, 79) (29518,) (1529, 79) (1529,)
# Epoch 1/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - loss: 1.1096 - val_loss: 0.7286
# Epoch 2/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.5593 - val_loss: 0.6779
# Epoch 3/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.4603 - val_loss: 0.3606
# Epoch 4/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.3748 - val_loss: 0.3964
# Epoch 5/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 0.3058 - val_loss: 0.2224
# Epoch 6/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.2484 - val_loss: 0.2440
# Epoch 7/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.2165 - val_loss: 0.3403
# Epoch 8/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1930 - val_loss: 0.3014
# Epoch 9/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1661 - val_loss: 0.3551
# Epoch 10/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1602 - val_loss: 0.2997
# Epoch 11/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1483 - val_loss: 0.2919
# Epoch 12/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.1347 - val_loss: 0.2768
# Epoch 13/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1273 - val_loss: 0.2471
# Epoch 14/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1211 - val_loss: 0.2805
# Epoch 15/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1106 - val_loss: 0.3289
# Epoch 16/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1201 - val_loss: 0.2714
# Epoch 17/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1052 - val_loss: 0.2782
# Epoch 18/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1027 - val_loss: 0.3062
# Epoch 19/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.1070 - val_loss: 0.3106
# Epoch 20/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0911 - val_loss: 0.3351
# Epoch 21/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0916 - val_loss: 0.3543
# Epoch 22/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0813 - val_loss: 0.3804
# Epoch 23/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0891 - val_loss: 0.3768
# Epoch 24/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0736 - val_loss: 0.3819
# Epoch 25/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0805 - val_loss: 0.3569
# Epoch 26/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0723 - val_loss: 0.3254
# Epoch 27/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0808 - val_loss: 0.3364
# Epoch 28/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0772 - val_loss: 0.3749
# Epoch 29/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0672 - val_loss: 0.3849
# Epoch 30/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - loss: 0.0716 - val_loss: 0.4276
# Epoch 31/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0639 - val_loss: 0.4049
# Epoch 32/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0666 - val_loss: 0.4112
# Epoch 33/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0723 - val_loss: 0.4209
# Epoch 34/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0660 - val_loss: 0.4240
# Epoch 35/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0636 - val_loss: 0.4502
# Epoch 36/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0639 - val_loss: 0.3899
# Epoch 37/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0601 - val_loss: 0.3935
# Epoch 38/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0689 - val_loss: 0.4454
# Epoch 39/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0615 - val_loss: 0.4296
# Epoch 40/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0569 - val_loss: 0.3962
# Epoch 41/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0509 - val_loss: 0.4412
# Epoch 42/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0623 - val_loss: 0.3860
# Epoch 43/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0489 - val_loss: 0.4552
# Epoch 44/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0534 - val_loss: 0.4058
# Epoch 45/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0568 - val_loss: 0.4689
# Epoch 46/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0619 - val_loss: 0.4504
# Epoch 47/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0468 - val_loss: 0.4862
# Epoch 48/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0535 - val_loss: 0.4790
# Epoch 49/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0480 - val_loss: 0.4632
# Epoch 50/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0438 - val_loss: 0.4278
# Epoch 51/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0563 - val_loss: 0.4626
# Epoch 52/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0457 - val_loss: 0.4386
# Epoch 53/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 0.0595 - val_loss: 0.4849
# Epoch 54/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0507 - val_loss: 0.5256
# Epoch 55/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0452 - val_loss: 0.4799
# Epoch 56/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0456 - val_loss: 0.4860
# Epoch 57/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0458 - val_loss: 0.4953
# Epoch 58/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0370 - val_loss: 0.4841
# Epoch 59/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0437 - val_loss: 0.4745
# Epoch 60/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - loss: 0.0418 - val_loss: 0.4970
# Epoch 61/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0451 - val_loss: 0.5091
# Epoch 62/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0339 - val_loss: 0.5321
# Epoch 63/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0464 - val_loss: 0.4851
# Epoch 64/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0623 - val_loss: 0.4665
# Epoch 65/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0497 - val_loss: 0.5011
# Epoch 66/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0400 - val_loss: 0.4632
# Epoch 67/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0374 - val_loss: 0.5676
# Epoch 68/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0503 - val_loss: 0.5429
# Epoch 69/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0384 - val_loss: 0.5561
# Epoch 70/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0343 - val_loss: 0.5604
# Epoch 71/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0324 - val_loss: 0.5090
# Epoch 72/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0489 - val_loss: 0.6129
# Epoch 73/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0336 - val_loss: 0.5525
# Epoch 74/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0411 - val_loss: 0.4661
# Epoch 75/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0423 - val_loss: 0.5032
# Epoch 76/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0382 - val_loss: 0.5725
# Epoch 77/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0379 - val_loss: 0.5526
# Epoch 78/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0313 - val_loss: 0.5884
# Epoch 79/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0424 - val_loss: 0.5705
# Epoch 80/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0351 - val_loss: 0.4649
# Epoch 81/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0334 - val_loss: 0.5141
# Epoch 82/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0334 - val_loss: 0.5490
# Epoch 83/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0348 - val_loss: 0.4088
# Epoch 84/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0400 - val_loss: 0.4641
# Epoch 85/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0388 - val_loss: 0.5038
# Epoch 86/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0400 - val_loss: 0.5252
# Epoch 87/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0361 - val_loss: 0.5457
# Epoch 88/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0407 - val_loss: 0.5071
# Epoch 89/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0320 - val_loss: 0.5838
# Epoch 90/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0356 - val_loss: 0.5183
# Epoch 91/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0479 - val_loss: 0.4882
# Epoch 92/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0264 - val_loss: 0.5666
# Epoch 93/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0401 - val_loss: 0.4840
# Epoch 94/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0306 - val_loss: 0.5422
# Epoch 95/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0393 - val_loss: 0.4715
# Epoch 96/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0317 - val_loss: 0.4986
# Epoch 97/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0307 - val_loss: 0.5184
# Epoch 98/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0330 - val_loss: 0.5318
# Epoch 99/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0339 - val_loss: 0.5472
# Epoch 100/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 0.0310 - val_loss: 0.5617
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 0.3787896414629624

# %%
df_train = pd.read_csv("/kaggle/input/vk-contest-mle/train_df.csv")
df_test = pd.read_csv("/kaggle/input/vk-contest-mle/test_df.csv")

X_train = df_train[df_train.columns[1:-1]].to_numpy()
X_test = df_test[df_test.columns[1:-1]].to_numpy()

y_train = df_train["target"].to_numpy()
y_test = df_test["target"].to_numpy()

X_train, y_train = SMOTE().fit_resample(X_train, y_train)

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)

X_scaler = StandardScaler().fit(np.concatenate((X_train, X_test)))

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

model = Sequential([
    Dense(1024, activation="relu"),
    Dropout(0.2),
    Dense(1024, activation="relu"),
    Dropout(0.2),
    Dense(1, activation="sigmoid")
])

model.compile(optimizer=Adam(learning_rate=1e-3), loss='binary_crossentropy')

history = model.fit(x=X_train_scaled, y=y_train, 
                    batch_size=128, epochs=10,
                    validation_data=[X_test_scaled, y_test])

y_pred = model.predict(X_test_scaled)
print(ndcg_score([y_test],[y_pred[:, 0]]))
# Out:
# (29518, 79) (29518,) (1529, 79) (1529,)
# Epoch 1/10
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - loss: 0.4189 - val_loss: 0.2214
# Epoch 2/10
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.1165 - val_loss: 0.2334
# Epoch 3/10
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0725 - val_loss: 0.2829
# Epoch 4/10
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0434 - val_loss: 0.2954
# Epoch 5/10
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0432 - val_loss: 0.2775
# Epoch 6/10
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0300 - val_loss: 0.3328
# Epoch 7/10
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0257 - val_loss: 0.3142
# Epoch 8/10
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0204 - val_loss: 0.3204
# Epoch 9/10
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0200 - val_loss: 0.3454
# Epoch 10/10
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0199 - val_loss: 0.2932
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 0.3957502073431586
